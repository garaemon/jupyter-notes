# %% [markdown]
# # x-yのプロットの例
# 元ネタは[こちら](https://matplotlib.org/stable/plot_types/basic/plot.html#sphx-glr-plot-types-basic-plot-py)

# %%
# !pip install matplotlib numpy
# Out:
# ...
#
# [notice] A new release of pip is available: 23.0.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# 0から10までのデータを100個作る
x = np.linspace(0, 10, 100)
# y = 4+1*sin(2x)
y = 4 + 1 * np.sin(2*x)

fig, ax = plt.subplots() # グラフの枠を作る
ax.plot(x, y)
plt.show()

# %% [markdown]
# プロットを実線ではなくて、サンプル上にxを打つようにしてみる

# %%
fig,ax = plt.subplots()
ax.plot(x,y,'x')
plt.show()

# %% [markdown]
# 実線も同時に表示する場合は、 `x-`を利用する。

# %%
fig,ax = plt.subplots()
ax.plot(x,y,'x-')
plt.show()

# %% [markdown]
# `x`の代わりに、点をプロットすることもできる。その場合、`x`の代わりに`o`, `x-`の代わりに`o-`を使う。

# %%
fig,ax = plt.subplots()
ax.plot(x,y,'o-')
plt.show()

# %% [markdown]
# 次に、gridを表示してみる。

# %%
fig,ax = plt.subplots()
ax.plot(x, y)
ax.grid()
plt.show()

# %% [markdown]
# 表示の範囲を狭める

# %%
fig,ax = plt.subplots()
ax.plot(x, y)
ax.set_xlim(1, 9)
plt.show()
